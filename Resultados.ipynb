# %%
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean
df = pd.read_csv("timingSort_results-RandomS.csv")
count1 = 0
count2 = 0
count3 = 0
x_values = df["Algoritmo"].drop_duplicates().tolist()

y_values = list(df["Algoritmo"].value_counts())
df1= df[df["Algoritmo"] == "merge-sort"]["Tiempo (microsegundos)"].mean()
df2= df[df["Algoritmo"] == "selection-sort"]["Tiempo (microsegundos)"].mean()
df3 = df[df["Algoritmo"] == "quick-sort"]["Tiempo (microsegundos)"].mean()
promedios = [df1, df2, df3]
plt.bar(x_values, promedios)
# Out:
# <BarContainer object of 3 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean
df = pd.read_csv("timingSort_results-ReverseSortedS.csv")
count1 = 0
count2 = 0
count3 = 0
x_values = df["Algoritmo"].drop_duplicates().tolist()

y_values = list(df["Algoritmo"].value_counts())
df1= df[df["Algoritmo"] == "merge-sort"]["Tiempo (microsegundos)"].mean()
df2= df[df["Algoritmo"] == "selection-sort"]["Tiempo (microsegundos)"].mean()
df3 = df[df["Algoritmo"] == "quick-sort"]["Tiempo (microsegundos)"].mean()
promedios = [df1, df2, df3]
plt.bar(x_values, promedios)
# Out:
# <BarContainer object of 3 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean
df = pd.read_csv("timingSort_results-SemiSortedS.csv")
count1 = 0
count2 = 0
count3 = 0
x_values = df["Algoritmo"].drop_duplicates().tolist()

y_values = list(df["Algoritmo"].value_counts())
df1= df[df["Algoritmo"] == "merge-sort"]["Tiempo (microsegundos)"].mean()
df2= df[df["Algoritmo"] == "selection-sort"]["Tiempo (microsegundos)"].mean()
df3 = df[df["Algoritmo"] == "quick-sort"]["Tiempo (microsegundos)"].mean()
promedios = [df1, df2, df3]
plt.bar(x_values, promedios)
# Out:
# <BarContainer object of 3 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean
df = pd.read_csv("timingSort_results-SortedS.csv")
count1 = 0
count2 = 0
count3 = 0
x_values = df["Algoritmo"].drop_duplicates().tolist()

y_values = list(df["Algoritmo"].value_counts())
df1= df[df["Algoritmo"] == "merge-sort"]["Tiempo (microsegundos)"].mean()
df2= df[df["Algoritmo"] == "selection-sort"]["Tiempo (microsegundos)"].mean()
df3 = df[df["Algoritmo"] == "quick-sort"]["Tiempo (microsegundos)"].mean()
promedios = [df1, df2, df3]
plt.bar(x_values, promedios)
# Out:
# <BarContainer object of 3 artists>
